# %% [markdown]
# # NumPy Random

# %% [raw]
# #Introduction:
# Random number does NOT mean a different number every time. Random means something that can not be predicted logically.

# %%
#Generate a random integer from 0 to 50
from numpy import random
x = random.randint(50)
print(x)
# Out:
# 21

# %%
#Generate a random float from 0 to 1
from numpy import random
x = random.rand()
print(x)
# Out:
# 0.3939582759696594

# %%
#Generate a 2-D array with 3 rows, each row containing 5 random integers from 0 to 100
from numpy import random
x = random.randint(50, size=(2, 5))
print(x)
# Out:
# [[38 46 36 30 43]
#  [18 39 36 27 27]]

# %%
#Return one of the values in an array
from numpy import random
x = random.choice([2,5,1,8])
print(x)
# Out:
# 1

# %%
#Data Distribution:
#Probability Density Function: A function that describes a continuous probability. i.e. probability of all values in an array.

# %%
#Generate a 1-D array containing 100 values, where each value has to be 2, 5, 1 or 8
#The probability for the value to be 2 is set to be 0.1
#The probability for the value to be 5 is set to be 0.3
#The probability for the value to be 1 is set to be 0.6
#The probability for the value to be 8 is set to be 0
from numpy import random
x = random.choice([2,5,1,8], p=[0.1, 0.3, 0.6, 0.0], size=(25))
print(x)
# Out:
# [1 2 1 2 1 5 1 1 1 1 1 1 5 5 1 1 5 1 1 5 5 5 5 1 5]

# %%
#Permutations of Elements:
#Randomly shuffle elements of following array
from numpy import random
import numpy as np
arr = np.array([1, 2, 3, 4, 5])
random.shuffle(arr)
print(arr)
# Out:
# [2 3 5 4 1]

# %%
#Generate a random permutation of elements of following array
from numpy import random
import numpy as np
arr = np.array([1, 2, 3, 4, 5])

print(random.permutation(arr))
# Out:
# [4 2 1 5 3]

# %%
#Seaborn:

# %%
#Import Matplotlib
import matplotlib.pyplot as plt

# %%
#Import Seaborn
import seaborn as sns

# %%
#Plotting a Distplot
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot([0, 1, 2, 3, 4, 5])
plt.show()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\3828670117.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5])
# C:\Users\Ajay\anaconda3\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Plotting a Distplot Without the Histogram
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot([0, 1, 2, 3, 4, 5], hist=False)
plt.show()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\2230517074.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5], hist=False)
# C:\Users\Ajay\anaconda3\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Normal Distribution:

# %%
#Generate a random normal distribution of size 3x4
from numpy import random
x = random.normal(size=(3,4))
print(x)
# Out:
# [[ 1.4469393   1.55044857  1.34836007 -0.05579319]
#  [ 0.25716978 -0.08522082  2.07623701 -0.16659489]
#  [-1.01292141 -0.40589798  0.74949021 -1.83332143]]

# %%
#Generate a random normal distribution of size 3x4 with mean at 3 and standard deviation of 4
from numpy import random
x = random.normal(loc=3, scale=4, size=(3,4))
print(x)
# Out:
# [[ 2.65610081  2.23453443 -0.35317244 -7.04291856]
#  [ 8.48010478  1.75774165  9.20303131  4.42755945]
#  [ 7.21156111  1.37173104  3.24363495  3.45676518]]

# %%
#Visualization of Normal Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(size=500), hist=False)
plt.show()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\2885920.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=500), hist=False)
# C:\Users\Ajay\anaconda3\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Binomial Distribution:

# %%
#Given 15 trials for coin toss generate 8 data points
from numpy import random
x = random.binomial(n=15, p=0.6, size=8)
print(x)
# Out:
# [ 5 10 14  7 11 10  4  8]

# %%
#Visualization of Binomial Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.binomial(n=10, p=0.5, size=400), hist=True, kde=False)
plt.show()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\599851396.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10, p=0.5, size=400), hist=True, kde=False)

# %%
#Difference Between Normal and Binomial Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(loc=50, scale=5, size=500), hist=False, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=500), hist=False, label='binomial')
plt.show()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\3939315359.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=5, size=500), hist=False, label='normal')
# C:\Users\Ajay\anaconda3\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\3939315359.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
# ...

# %%
#Poisson Distribution:

# %%
#Generate a random 1x10 distribution for occurrence 3
from numpy import random
x = random.poisson(lam=3, size=15)
print(x)
# Out:
# [1 4 2 2 2 2 0 4 3 3 4 4 3 2 2]

# %%
#Visualization of Poisson Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.poisson(lam=3, size=500), kde=False)
plt.show()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\1745928319.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=3, size=500), kde=False)

# %%
#Difference Between Normal and Poisson Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(loc=100, scale=7, size=500), hist=False, label='normal')
sns.distplot(random.poisson(lam=100, size=500), hist=False, label='poisson')
plt.show()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\3213174108.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=100, scale=7, size=500), hist=False, label='normal')
# C:\Users\Ajay\anaconda3\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\3213174108.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
# ...

# %%
#Difference Between Binomial and Poisson Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.binomial(n=1000, p=0.01, size=1000), hist=False, label='binomial')
sns.distplot(random.poisson(lam=10, size=1000), hist=False, label='poisson')
plt.show()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\3265237806.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=1000, p=0.01, size=1000), hist=False, label='binomial')
# C:\Users\Ajay\anaconda3\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\3265237806.py:6: UserWarning:
#
# ...

# %%
#Uniform Distribution:

# %%
#Create a 2x3 uniform distribution sample
from numpy import random
x = random.uniform(size=(4, 2))
print(x)
# Out:
# [[0.05274774 0.5432939 ]
#  [0.32585724 0.05706658]
#  [0.14863185 0.82414314]
#  [0.1112855  0.09715459]]

# %%
#Visualization of Uniform Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.uniform(size=500), hist=False)
plt.show()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\685464333.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.uniform(size=500), hist=False)
# C:\Users\Ajay\anaconda3\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Logistic Distribution"

# %%
#Draw 2x3 samples from a logistic distribution with mean at 1 and stddev 2.0
from numpy import random
x = random.logistic(loc=1, scale=2, size=(2, 3))
print(x)
# Out:
# [[ 1.68235314 12.23539153  7.43227021]
#  [ 0.94924729 -5.10206426 -0.42360314]]

# %%
#Visualization of Logistic Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.logistic(size=500), hist=False)
plt.show()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\1091335641.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.logistic(size=500), hist=False)
# C:\Users\Ajay\anaconda3\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Difference Between Logistic and Normal Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(scale=2, size=500), hist=False, label='normal')
sns.distplot(random.logistic(size=500), hist=False, label='logistic')
plt.show()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\2161779081.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(scale=2, size=500), hist=False, label='normal')
# C:\Users\Ajay\anaconda3\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\2161779081.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
#Multinomial Distribution

# %%
#Draw out a sample for dice roll:
from numpy import random
x = random.multinomial(n=6, pvals=[1/6, 1/6, 1/6, 1/6, 1/6, 1/6])
print(x)
# Out:
# [1 2 1 0 0 2]

# %%
#Exponential Distribution:

# %%
#Draw out a sample for exponential distribution with 2.0 scale with 2x3 size
from numpy import random
x = random.exponential(scale=2, size=(2, 3))
print(x)
# Out:
# [[1.2888342  4.91208237 0.746413  ]
#  [0.64059732 1.69459577 0.89091924]]

# %%
#Visualization of Exponential Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.exponential(size=500), hist=False)
plt.show()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\4104046199.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.exponential(size=500), hist=False)
# C:\Users\Ajay\anaconda3\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Chi Square Distribution

# %%
#Draw out a sample for chi squared distribution with degree of freedom 4 with size 2x3
from numpy import random
x = random.chisquare(df=4, size=(2, 3))
print(x)
# Out:
# [[0.15971429 3.54398119 2.58819966]
#  [2.93566576 3.31384558 4.50138503]]

# %%
#Visualization of Chi Square Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.chisquare(df=4, size=500), hist=False)
plt.show()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\333412475.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.chisquare(df=4, size=500), hist=False)
# C:\Users\Ajay\anaconda3\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Rayleigh Distribution

# %%
#Draw out a sample for rayleigh distribution with scale of 2 with size 2x3
from numpy import random
x = random.rayleigh(scale=2, size=(2, 3))
print(x)
# Out:
# [[2.87935698 1.74714063 2.15491323]
#  [2.99550062 1.17018187 2.02971133]]

# %%
#Visualization of Rayleigh Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.rayleigh(size=500), hist=False)
plt.show()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\144421516.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.rayleigh(size=500), hist=False)
# C:\Users\Ajay\anaconda3\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Pareto Distribution

# %%
#Draw out a sample for pareto distribution with shape of 2 with size 2x3
from numpy import random
x = random.pareto(a=2, size=(2, 3))
print(x)
# Out:
# [[0.26477291 3.33696165 7.12240514]
#  [0.22676996 0.51935033 0.20457226]]

# %%
#Visualization of Pareto Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.pareto(a=2, size=500), kde=False)
plt.show()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\838042819.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.pareto(a=2, size=500), kde=False)

# %%
#Zipf Distribution:

# %%
#Draw out a sample for zipf distribution with distribution parameter 2 with size 2x3
from numpy import random
x = random.zipf(a=2, size=(2, 3))
print(x)
# Out:
# [[2 1 1]
#  [1 1 1]]

# %%
#Visualization of Zipf Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
x = random.zipf(a=2, size=500)
sns.distplot(x[x<10], kde=False)
plt.show()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_17736\1023012206.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x[x<10], kde=False)
